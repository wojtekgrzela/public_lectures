# %%
# import data

import pandas as pd

data = pd.read_excel('input_data.xlsx')

data
# Out:
#         city                    country     area  population  \
# 0   New York                         US  1213.37   8175133.0
# 1   New York                        USA      NaN   8175133.0
# 2   New York   United States of America      NaN         NaN
# 3   New York                    America      NaN         NaN
# 4   New York                        USA  1213.37         NaN
# 5     Kraków                     Poland      NaN         NaN
# 6     Kraków                         PL   326.85    774839.0
# 7     Kraków                     Polska   326.85         NaN
# 8     Kraków                     Poland   326.85         NaN
# 9     Kraków                     Poland   326.85         NaN
# 10  Warszawa                     Poland      NaN   1783321.0
# 11  Warszawa                     Polska      NaN         NaN
# 12  Warszawa                     Poland   517.24         NaN
# 13  Warszawa                     Poland      NaN         NaN
# 14  Warszawa                     Poland      NaN         NaN
#
#                          monument          president
# 0           Empire State Building     Bill de Blasio
# 1                   Central Park      Bill de Blasio
# 2              Statue of Liberty      Bill de Blasio
# 3         St. Patrick's Cathedral     Bill de Blasio
# 4                    Times Square     Bill de Blasio
# 5                           Wawel                NaN
# 6                       Kazimierz                NaN
# 7         Church of St. Adalbert                 NaN
# 8        Juliusz Słowacki Theatre                NaN
# 9             Saint Anne's Church                NaN
# 10  Palace of Culture and Science  Rafał Trzaskowski
# 11                            NaN  Rafał Trzaskowski
# 12             Jabłonowski Palace  Rafał Trzaskowski
# 13              Holy Cross Church  Rafał Trzaskowski
# 14           Three Crosses Square  Rafał Trzaskowski

# %%
# read heders

print(data.columns)
# Out:
# Index(['city', 'country', 'area', 'population', 'monument', 'president'], dtype='object')

# %%
data.area.describe()
# Out:
# count       7.000000
# mean      607.340000
# std       419.793857
# min       326.850000
# 25%       326.850000
# 50%       326.850000
# 75%       865.305000
# max      1213.370000
# Name: area, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        15 non-null     object
#  1   country     15 non-null     object
#  2   area        7 non-null      float64
#  3   population  4 non-null      float64
#  4   monument    14 non-null     object
#  5   president   10 non-null     object
# dtypes: float64(2), object(4)
# memory usage: 848.0+ bytes

# %%
# find all unique city

all_city = data['city'].unique()
print("City array: {0}".format(all_city))

# find all unique country

all_country = data['country'].unique()
print("Country array: {0}".format(all_country))
# Out:
# City array: ['New York' 'Kraków' 'Warszawa']
# Country array: ['US' 'USA' ' United States of America' 'America' 'Poland' 'PL' 'Polska']

# %%
# mapping value
dicionary_corect = {'US':'USA', 'USA':'USA', ' United States of America':'USA', 'America':'USA', 'Poland':'POL', 'PL':'POL', 'Polska':'POL' }
mapping_country = data['country'].map(dicionary_corect)

data['country'] = mapping_country

data
# Out:
#         city country     area  population                       monument  \
# 0   New York     USA  1213.37   8175133.0          Empire State Building
# 1   New York     USA      NaN   8175133.0                  Central Park
# 2   New York     USA      NaN         NaN             Statue of Liberty
# 3   New York     USA      NaN         NaN        St. Patrick's Cathedral
# 4   New York     USA  1213.37         NaN                   Times Square
# 5     Kraków     POL      NaN         NaN                          Wawel
# 6     Kraków     POL   326.85    774839.0                      Kazimierz
# 7     Kraków     POL   326.85         NaN        Church of St. Adalbert
# 8     Kraków     POL   326.85         NaN       Juliusz Słowacki Theatre
# 9     Kraków     POL   326.85         NaN            Saint Anne's Church
# 10  Warszawa     POL      NaN   1783321.0  Palace of Culture and Science
# 11  Warszawa     POL      NaN         NaN                            NaN
# 12  Warszawa     POL   517.24         NaN             Jabłonowski Palace
# 13  Warszawa     POL      NaN         NaN              Holy Cross Church
# 14  Warszawa     POL      NaN         NaN           Three Crosses Square
#
#             president
# 0      Bill de Blasio
# 1      Bill de Blasio
# 2      Bill de Blasio
# 3      Bill de Blasio
# 4      Bill de Blasio
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10  Rafał Trzaskowski
# 11  Rafał Trzaskowski
# 12  Rafał Trzaskowski
# 13  Rafał Trzaskowski
# 14  Rafał Trzaskowski

# %%
# check area and population value

for city in all_city:
    # get uniqe value area and population for the city
    area = data[(data['city']==city) & (~data['area'].isna())]['area'].unique()
    population = data[(data['city']==city) & (~data['population'].isna())]['population'].unique()
    if len(area) == 1:
        data.loc[(data['city']==city) & (data['area'].isna()), 'area'] = area
    else:
        print('Area data mismatch on the context of {0}'.format(city))
        
    if len(population) == 1:
        data.loc[(data['city']==city) & (data['population'].isna()), 'population'] = population
    else:
        print('Population data mismatch on the context of {0}'.format(city))

data
# Out:
#         city country     area  population                       monument  \
# 0   New York     USA  1213.37   8175133.0          Empire State Building
# 1   New York     USA  1213.37   8175133.0                  Central Park
# 2   New York     USA  1213.37   8175133.0             Statue of Liberty
# 3   New York     USA  1213.37   8175133.0        St. Patrick's Cathedral
# 4   New York     USA  1213.37   8175133.0                   Times Square
# 5     Kraków     POL   326.85    774839.0                          Wawel
# 6     Kraków     POL   326.85    774839.0                      Kazimierz
# 7     Kraków     POL   326.85    774839.0        Church of St. Adalbert
# 8     Kraków     POL   326.85    774839.0       Juliusz Słowacki Theatre
# 9     Kraków     POL   326.85    774839.0            Saint Anne's Church
# 10  Warszawa     POL   517.24   1783321.0  Palace of Culture and Science
# 11  Warszawa     POL   517.24   1783321.0                            NaN
# 12  Warszawa     POL   517.24   1783321.0             Jabłonowski Palace
# 13  Warszawa     POL   517.24   1783321.0              Holy Cross Church
# 14  Warszawa     POL   517.24   1783321.0           Three Crosses Square
#
#             president
# 0      Bill de Blasio
# 1      Bill de Blasio
# 2      Bill de Blasio
# 3      Bill de Blasio
# 4      Bill de Blasio
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10  Rafał Trzaskowski
# 11  Rafał Trzaskowski
# 12  Rafał Trzaskowski
# 13  Rafał Trzaskowski
# 14  Rafał Trzaskowski

# %%
# get country

country_list = pd.DataFrame(data['country'].unique(), columns=['country'])

country_list.index.name = 'id'

country_list
# Out:
#    country
# id
# 0      USA
# 1      POL

# %%
# get city and conect with country

city_list = data[['city','country']].drop_duplicates().reset_index().drop(columns = ['index']);
city_list.index.name = 'id'

city_list = city_list.rename(columns = {'country':'country_id'})

city_list
# Out:
#         city country_id
# id
# 0   New York        USA
# 1     Kraków        POL
# 2   Warszawa        POL

# %%
city_list['country_id'] = city_list['country_id'].map(lambda x:  country_list[country_list['country'] == x].index.values.astype(int)[0])

city_list
# Out:
#         city  country_id
# id
# 0   New York           0
# 1     Kraków           1
# 2   Warszawa           1

# %%
# get area and population

city_pop_area = data[['city','area', 'population', 'president']].drop_duplicates().reset_index().drop(columns = ['index']);
city_pop_area.index.name = 'id'

city_pop_area = city_pop_area.rename(columns = {'city':'city_id'})

city_pop_area['city_id'] = city_pop_area['city_id'].map(lambda x:  city_list[city_list['city'] == x].index.values.astype(int)[0])

city_pop_area
# Out:
#     city_id     area  population          president
# id
# 0         0  1213.37   8175133.0     Bill de Blasio
# 1         1   326.85    774839.0                NaN
# 2         2   517.24   1783321.0  Rafał Trzaskowski

# %%
# get city and monument

city_monuments = data[['city', 'monument']].drop_duplicates().dropna().reset_index().drop(columns = ['index']);
city_monuments.index.name = 'id'

city_monuments = city_monuments.rename(columns = {'city':'city_id'})

city_monuments['city_id'] = city_monuments['city_id'].map(lambda x:  city_list[city_list['city'] == x].index.values.astype(int)[0])

city_monuments
# Out:
#     city_id                       monument
# id
# 0         0          Empire State Building
# 1         0                  Central Park
# 2         0             Statue of Liberty
# 3         0        St. Patrick's Cathedral
# 4         0                   Times Square
# 5         1                          Wawel
# 6         1                      Kazimierz
# 7         1        Church of St. Adalbert
# 8         1       Juliusz Słowacki Theatre
# 9         1            Saint Anne's Church
# 10        2  Palace of Culture and Science
# 11        2             Jabłonowski Palace
# 12        2              Holy Cross Church
# 13        2           Three Crosses Square

# %%
#Table definition and insert data

from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base

# db_string = "postgres://postgres:postgres@127.0.0.1:5432/testAGH"
db_string = "postgresql://postgres:xxx@localhost/Advanced_Databases"

engine = create_engine(db_string)

Base = declarative_base()

# Import column structure and constraints

from sqlalchemy import Column, Integer, String, Float, ForeignKey, Sequence, CheckConstraint, UniqueConstraint

class Country(Base):
    __tablename__ = 'countryies'
    __table_args__ = (
        CheckConstraint('len(country) = 3'),
        UniqueConstraint('country'),
    )
    id = Column(Integer, Sequence('seq_country_id'), primary_key = True)
    country = Column(String(50), nullable = False)

class City(Base):
    __tablename__ = 'cities'
    __table_args__ = (
        CheckConstraint('len(city) > 0'),
    )
    id = Column(Integer, Sequence('seq_city_id'), primary_key=True)
    country_id = Column(Integer, ForeignKey('countries.id'))
    city = Column(String, nullable = False)
    
class City_data(Base):
    __tablename__ = 'city_data'
    __table_args__ = (
        CheckConstraint('area > 0'),
        CheckConstraint('population >= 0')
    )
    id = Column(Integer, Sequence('seq_city_data_id'), primary_key=True )
    city_id = Column(Integer, ForeignKey('cityies.id'))
    area = Column(Float, nullable = False,  default=0)
    population = Column(Integer, nullable = False,  default=0)
    president = Column(String(60), nullable = True, default='')
    
class Monument(Base):
    __tablename__ = 'monuments'
    __table_args__ = (
        CheckConstraint('len(monument) > 0'),
    )
    id = Column(Integer, Sequence('seq_monument_id'), primary_key=True )
    city_id = Column(Integer, ForeignKey('cityies.id'))
    monument = Column(String(100), nullable = True)

Base.metadata.create_all(engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2284         try:
# -> 2285             return fn()
#    2286         except dialect.dbapi.Error as e:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     656             with util.safe_reraise():
# --> 657                 pool.logger.debug("Error on connect(): %s", e)
#     658         else:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     651             self.starttime = time.time()
# --> 652             connection = pool._invoke_creator(self)
#     653             pool.logger.debug("Created new connection %r", connection)
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     487         # inherits the docstring from interfaces.Dialect.connect
# --> 488         return self.dbapi.connect(*cargs, **cparams)
#     489
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#
# OperationalError:
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-42-80cf80e10738> in <module>
#      53     monument = Column(String(100), nullable = True)
#      54
# ---> 55 Base.metadata.create_all(engine)
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\sql\schema.py in create_all(self, bind, tables, checkfirst)
#    4319             bind = _bind_or_error(self)
#    4320         bind._run_visitor(
# -> 4321             ddl.SchemaGenerator, self, checkfirst=checkfirst, tables=tables
#    4322         )
#    4323
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\base.py in _run_visitor(self, visitorcallable, element, connection, **kwargs)
#    2055         self, visitorcallable, element, connection=None, **kwargs
#    2056     ):
# -> 2057         with self._optional_conn_ctx_manager(connection) as conn:
#    2058             conn._run_visitor(visitorcallable, element, **kwargs)
#    2059
#
# C:\Tools\Anaconda\envs\test-env\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    2047     def _optional_conn_ctx_manager(self, connection=None):
#    2048         if connection is None:
# -> 2049             with self._contextual_connect() as conn:
#    2050                 yield conn
#    2051         else:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2249         return self._connection_cls(
#    2250             self,
# -> 2251             self._wrap_pool_connect(self.pool.connect, None),
#    2252             close_with_result=close_with_result,
#    2253             **kwargs
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2287             if connection is None:
#    2288                 Connection._handle_dbapi_exception_noconnection(
# -> 2289                     e, dialect, self
#    2290                 )
#    2291             else:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1553         elif should_wrap:
#    1554             util.raise_(
# -> 1555                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1556             )
#    1557         else:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2283         dialect = self.dialect
#    2284         try:
# -> 2285             return fn()
#    2286         except dialect.dbapi.Error as e:
#    2287             if connection is None:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     361         """
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#     365         try:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     771     def _checkout(cls, pool, threadconns=None, fairy=None):
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#     775             fairy._pool = pool
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     137             except:
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#     141             return self._do_get()
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     134         if self._inc_overflow():
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#     138                 with util.safe_reraise():
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655         except Exception as e:
#     656             with util.safe_reraise():
# --> 657                 pool.logger.debug("Error on connect(): %s", e)
#     658         else:
#     659             if first_connect_check:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     650         try:
#     651             self.starttime = time.time()
# --> 652             connection = pool._invoke_creator(self)
#     653             pool.logger.debug("Created new connection %r", connection)
#     654             self.connection = connection
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     486     def connect(self, *cargs, **cparams):
#     487         # inherits the docstring from interfaces.Dialect.connect
# --> 488         return self.dbapi.connect(*cargs, **cparams)
#     489
#     490     def create_connect_args(self, url):
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     124
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#     128         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError)
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
country_list.to_sql('countryies',engine, if_exists='append')
city_list.to_sql('cityies',engine, if_exists='append')
city_pop_area.to_sql('city_data',engine, if_exists='append')
city_monuments.to_sql('monuments',engine, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2284         try:
# -> 2285             return fn()
#    2286         except dialect.dbapi.Error as e:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     656             with util.safe_reraise():
# --> 657                 pool.logger.debug("Error on connect(): %s", e)
#     658         else:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     651             self.starttime = time.time()
# --> 652             connection = pool._invoke_creator(self)
#     653             pool.logger.debug("Created new connection %r", connection)
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     487         # inherits the docstring from interfaces.Dialect.connect
# --> 488         return self.dbapi.connect(*cargs, **cparams)
#     489
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#
# OperationalError:
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-43-2b997ab6b69e> in <module>
# ----> 1 country_list.to_sql('countryies',engine, if_exists='append')
#       2 city_list.to_sql('cityies',engine, if_exists='append')
#       3 city_pop_area.to_sql('city_data',engine, if_exists='append')
#       4 city_monuments.to_sql('monuments',engine, if_exists='append')
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1314             dtype=dtype,
#    1315         )
# -> 1316         table.create()
#    1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\pandas\io\sql.py in create(self)
#     642
#     643     def create(self):
# --> 644         if self.exists():
#     645             if self.if_exists == "fail":
#     646                 raise ValueError(f"Table '{self.name}' already exists.")
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\pandas\io\sql.py in exists(self)
#     629
#     630     def exists(self):
# --> 631         return self.pd_sql.has_table(self.name, self.schema)
#     632
#     633     def sql_schema(self):
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1339     def has_table(self, name, schema=None):
#    1340         return self.connectable.run_callable(
# -> 1341             self.connectable.dialect.has_table, name, schema or self.meta.schema
#    1342         )
#    1343
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2169
#    2170         """
# -> 2171         with self._contextual_connect() as conn:
#    2172             return conn.run_callable(callable_, *args, **kwargs)
#    2173
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2249         return self._connection_cls(
#    2250             self,
# -> 2251             self._wrap_pool_connect(self.pool.connect, None),
#    2252             close_with_result=close_with_result,
#    2253             **kwargs
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2287             if connection is None:
#    2288                 Connection._handle_dbapi_exception_noconnection(
# -> 2289                     e, dialect, self
#    2290                 )
#    2291             else:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1553         elif should_wrap:
#    1554             util.raise_(
# -> 1555                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1556             )
#    1557         else:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2283         dialect = self.dialect
#    2284         try:
# -> 2285             return fn()
#    2286         except dialect.dbapi.Error as e:
#    2287             if connection is None:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     361         """
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#     365         try:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     771     def _checkout(cls, pool, threadconns=None, fairy=None):
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#     775             fairy._pool = pool
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     137             except:
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#     141             return self._do_get()
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     134         if self._inc_overflow():
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#     138                 with util.safe_reraise():
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655         except Exception as e:
#     656             with util.safe_reraise():
# --> 657                 pool.logger.debug("Error on connect(): %s", e)
#     658         else:
#     659             if first_connect_check:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     650         try:
#     651             self.starttime = time.time()
# --> 652             connection = pool._invoke_creator(self)
#     653             pool.logger.debug("Created new connection %r", connection)
#     654             self.connection = connection
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     486     def connect(self, *cargs, **cparams):
#     487         # inherits the docstring from interfaces.Dialect.connect
# --> 488         return self.dbapi.connect(*cargs, **cparams)
#     489
#     490     def create_connect_args(self, url):
#
# C:\Tools\Anaconda\envs\test-env\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     124
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#     128         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError)
# (Background on this error at: http://sqlalche.me/e/e3q8)
