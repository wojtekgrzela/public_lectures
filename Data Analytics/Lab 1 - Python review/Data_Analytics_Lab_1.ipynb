# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('Data1.csv')

data.rename(columns={'Unnamed: 0':'Date'}, inplace=True)
kolumny = data.columns
print(kolumny)

# data.set_index('Date')
# data = data.set_index('Date')

# print(data)
# data.head()


plt.figure()
data = data.set_index('Date')
data.plot()


dataMelted = data.melt()
# print(data)
# print(dataMelted)

plt.figure()
grid = sns.FacetGrid(dataMelted, col="variable", col_wrap=3)
grid.map(plt.hist, "value")

# plt.figure()
# sns.distplot(data['theta_1'],kde=True)

for i in kolumny:
    if i == kolumny[0]:
        continue
    plt.figure()
    sns.distplot(data[i], kde=True, hist=False)
# sns.kdeplot(data)
# plt.show()


'''Data from year: 2018'''

data2018 = data['2018-01-01':'2019-01-01']

plt.figure()
data2018.plot()

kolumny2018 = data.columns
print(kolumny2018)

dataMelted2018 = data2018.melt()

plt.figure()
grid = sns.FacetGrid(dataMelted, col="variable", col_wrap=3)
grid.map(plt.hist, "value")

for i in range(1,5):
    plt.figure()
    sns.distplot(data[kolumny2018[i]], kde=True, hist=False)
# Out:
# Index(['Date', 'theta_1', 'theta_2', 'theta_3', 'theta_4', 'theta_5',
#        'theta_6'],
#       dtype='object')
# Index(['theta_1', 'theta_2', 'theta_3', 'theta_4', 'theta_5', 'theta_6'], dtype='object')
